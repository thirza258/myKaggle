# %%
import pandas as pd
import numpy as np

df = pd.read_csv('NASA_TechPort_20240914.csv')
df.head()
# Out:
#    TechPort ID  ...                                Project API URL
# 0       157631  ...  https://techport.nasa.gov/api/projects/157631
# 1        95938  ...   https://techport.nasa.gov/api/projects/95938
# 2       157042  ...  https://techport.nasa.gov/api/projects/157042
# 3       146499  ...  https://techport.nasa.gov/api/projects/146499
# 4       146252  ...  https://techport.nasa.gov/api/projects/146252
#
# [5 rows x 8 columns]
